# %% [markdown]
# # Importing Libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import emoji
import string
import nltk
from PIL import Image
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC,LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
import pickle

# %% [markdown]
# # Getting data

# %%
data = pd.read_csv('cyberbullying_tweets.csv')

# %% [markdown]
# # Initial Review

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47692 entries, 0 to 47691
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_text          47692 non-null  object
#  1   cyberbullying_type  47692 non-null  object
# dtypes: object(2)
# memory usage: 745.3+ KB

# %%
data.head()
# Out:
#                                           tweet_text cyberbullying_type
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %% [markdown]
# # Checking Missing Values

# %%
data.isnull().sum()
# Out:
# tweet_text            0
# cyberbullying_type    0
# dtype: int64

# %% [markdown]
# ## No Missing Values found!

# %%
data['cyberbullying_type'].value_counts()
# Out:
# religion               7998
# age                    7992
# gender                 7973
# ethnicity              7961
# not_cyberbullying      7945
# other_cyberbullying    7823
# Name: cyberbullying_type, dtype: int64

# %% [markdown]
# ## Renaming columns for better understanding

# %%
data = data.rename(columns={'tweet_text': 'text', 'cyberbullying_type': 'sentiment'})

# %%
data.head()
# Out:
#                                                 text          sentiment
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %% [markdown]
# ### Adding Encoded column for sentiments

# %%
data["sentiment_encoded"] = data['sentiment'].replace({"religion": 1, "age": 2, "ethnicity": 3, "gender": 4, "other_cyberbullying": 5,"not_cyberbullying": 6})

# %%
data.head()
# Out:
#                                                 text          sentiment  \
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    sentiment_encoded
# 0                  6
# 1                  6
# 2                  6
# 3                  6
# 4                  6

# %%
stop_words = set(stopwords.words('english'))

# %% [markdown]
# # Preprocessing of Text

# %% [markdown]
# ## Function to Remove Emojis

# %%
def strip_emoji(text):
    return emoji.replace_emoji(text,replace="")

# %% [markdown]
# ## Fucntion to Convert text to lowercase, remove (/r, /n  characters), URLs, non-utf characters, Numbers, punctuations,stopwords

# %%
def strip_all_entities(text): 
    text = text.replace('\r', '').replace('\n', ' ').lower()
    text = re.sub(r"(?:\@|https?\://)\S+", "", text)
    text = re.sub(r'[^\x00-\x7f]',r'', text)
    text = re.sub(r'(.)1+', r'1', text)
    text = re.sub('[0-9]+', '', text)
    stopchars= string.punctuation
    table = str.maketrans('', '', stopchars)
    text = text.translate(table)
    text = [word for word in text.split() if word not in stop_words]
    text = ' '.join(text)
    return text

# %% [markdown]
# ## Function to remove contractions

# %%
def decontract(text):
    text = re.sub(r"can\'t", "can not", text)
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    return text

# %% [markdown]
# ## Function to Clean Hashtags

# %%
def clean_hashtags(tweet):
    new_tweet = " ".join(word.strip() for word in re.split('#(?!(?:hashtag)\b)[\w-]+(?=(?:\s+#[\w-]+)*\s*$)', tweet))
    new_tweet2 = " ".join(word.strip() for word in re.split('#|_', new_tweet))
    return new_tweet2

# %% [markdown]
# ## Function to Filter Special Characters such as $, &

# %%
def filter_chars(a):
    sent = []
    for word in a.split(' '):
        if ('$' in word) | ('&' in word):
            sent.append('')
        else:
            sent.append(word)
    return ' '.join(sent)

# %% [markdown]
# ## Function to remove mutiple sequence spaces

# %%
def remove_mult_spaces(text):
    return re.sub("\s\s+" , " ", text)

# %% [markdown]
# ## Function to apply stemming to words

# %%
def stemmer(text):
    tokenized = nltk.word_tokenize(text)
    ps = PorterStemmer()
    return ' '.join([ps.stem(words) for words in tokenized])

# %% [markdown]
# ## Function to apply lemmatization to words

# %%
def lemmatize(text):
    tokenized = nltk.word_tokenize(text)
    lm = WordNetLemmatizer()
    return ' '.join([lm.lemmatize(words) for words in tokenized])

# %% [markdown]
# ## Function to Preprocess the text by applying all above functions

# %%
def preprocess(text):
    text = strip_emoji(text)
    text = decontract(text)
    text = strip_all_entities(text)
    text = clean_hashtags(text)
    text = filter_chars(text)
    text = remove_mult_spaces(text)
    text = stemmer(text)
    text = lemmatize(text)
    return text

# %%
data['cleaned_text'] = data['text'].apply(preprocess)
data.head()
# Out:
#                                                 text          sentiment  \
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    sentiment_encoded                                       cleaned_text
# 0                  6                 word katandandr food crapilici mkr
# 1                  6  aussietv white mkr theblock imacelebrityau tod...
# 2                  6                     classi whore red velvet cupcak
# 3                  6  meh p thank head concern anoth angri dude twitter
# 4                  6  isi account pretend kurdish account like islam...

# %% [markdown]
# ## Cleaned text added

# %% [markdown]
# ## Dealing with Duplicates

# %%
data["cleaned_text"].duplicated().sum()
# Out:
# 3041

# %%
data.drop_duplicates("cleaned_text", inplace=True)

# %% [markdown]
# # Duplicates removed

# %% [markdown]
# # Tokenization

# %%
data['tweet_list'] = data['cleaned_text'].apply(word_tokenize)
data.head()
# Out:
#                                                 text          sentiment  \
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    sentiment_encoded                                       cleaned_text  \
# 0                  6                 word katandandr food crapilici mkr
# 1                  6  aussietv white mkr theblock imacelebrityau tod...
# 2                  6                     classi whore red velvet cupcak
# 3                  6  meh p thank head concern anoth angri dude twitter
# 4                  6  isi account pretend kurdish account like islam...
#
#                                           tweet_list
# 0           [word, katandandr, food, crapilici, mkr]
# 1  [aussietv, white, mkr, theblock, imacelebritya...
# 2               [classi, whore, red, velvet, cupcak]
# 3  [meh, p, thank, head, concern, anoth, angri, d...
# 4  [isi, account, pretend, kurdish, account, like...

# %% [markdown]
# # Checking length of various tweet texts

# %%
text_len = []
for text in data.tweet_list:
    tweet_len = len(text)
    text_len.append(tweet_len)
data['text_len'] = text_len

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x='text_len', data=data, palette='mako')
plt.title('Count of words in tweets', fontsize=20)
plt.yticks([])
ax.bar_label(ax.containers[0])
plt.ylabel('count')
plt.xlabel('')
plt.show()

# %% [markdown]
# # Removing text without words

# %%
data = data[data['text_len']!=0]

# %%
data.shape
# Out:
# (44650, 6)

# %% [markdown]
# # Function to create WordCloud

# %%
def plot_wordcloud(cyberbullying_type):
    string = ""
    for i in data[data.sentiment == cyberbullying_type].cleaned_text.values:
        string = string + " " + i.strip()

    custom_mask = np.array(Image.open('statics/twitter.png'))
    mask_colors = ImageColorGenerator(custom_mask)
    wordcloud = WordCloud(background_color ='white',max_words=2000, max_font_size=256,
               random_state=42, width=custom_mask.shape[1],height=custom_mask.shape[0],
                mask = custom_mask,min_font_size = 10,color_func=mask_colors).generate(string)
 
    # plot the WordCloud image                      
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)
    plt.title(cyberbullying_type)
    plt.show()
    del string

# %% [markdown]
# # Splitting data based on sentiment for Data Exploration

# %%
not_cyberbullying_type = data[data['sentiment']=='not_cyberbullying']
gender_type = data[data['sentiment']=='gender']
religion_type = data[data['sentiment']=='religion']
other_cyberbullying_type = data[data['sentiment']=='other_cyberbullying']
age_type = data[data['sentiment']=='age']
ethnicity_type = data[data['sentiment']=='ethnicity']

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Gender Based Cyberbullying

# %%
gender = Counter([item for sublist in gender_type['tweet_list'] for item in sublist])
top20_gender = pd.DataFrame(gender.most_common(20))
top20_gender.columns = ['Top Words','Count']
top20_gender.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_dd06b_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_dd06b_row1_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_dd06b_row2_col1 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_dd06b_row3_col1 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_dd06b_row4_col1 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_dd06b_row5_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_dd06b_row6_col1 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_dd06b_row7_col1 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_dd06b_row8_col1 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_dd06b_row9_col1, #T_dd06b_row10_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_dd06b_row11_col1 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_dd06b_row12_col1, #T_dd06b_row13_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_dd06b_row14_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_dd06b_row15_col1, #T_dd06b_row16_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_dd06b_row17_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_dd06b_row18_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_dd06b_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_dd06b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Top Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd06b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd06b_row0_col0" class="data row0 col0" >joke</td>
#       <td id="T_dd06b_row0_col1" class="data row0 col1" >5179</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd06b_row1_col0" class="data row1 col0" >rape</td>
#       <td id="T_dd06b_row1_col1" class="data row1 col1" >4070</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd06b_row2_col0" class="data row2 col0" >gay</td>
#       <td id="T_dd06b_row2_col1" class="data row2 col1" >3852</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd06b_row3_col0" class="data row3 col0" >call</td>
#       <td id="T_dd06b_row3_col1" class="data row3 col1" >1401</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dd06b_row4_col0" class="data row4 col0" >make</td>
#       <td id="T_dd06b_row4_col1" class="data row4 col1" >1283</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dd06b_row5_col0" class="data row5 col0" >rt</td>
#       <td id="T_dd06b_row5_col1" class="data row5 col1" >1221</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dd06b_row6_col0" class="data row6 col0" >woman</td>
#       <td id="T_dd06b_row6_col1" class="data row6 col1" >1182</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dd06b_row7_col0" class="data row7 col0" >bitch</td>
#       <td id="T_dd06b_row7_col1" class="data row7 col1" >1146</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dd06b_row8_col0" class="data row8 col0" >femal</td>
#       <td id="T_dd06b_row8_col1" class="data row8 col1" >1108</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dd06b_row9_col0" class="data row9 col0" >peopl</td>
#       <td id="T_dd06b_row9_col1" class="data row9 col1" >988</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dd06b_row10_col0" class="data row10 col0" >like</td>
#       <td id="T_dd06b_row10_col1" class="data row10 col1" >978</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dd06b_row11_col0" class="data row11 col0" >sexist</td>
#       <td id="T_dd06b_row11_col1" class="data row11 col1" >953</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dd06b_row12_col0" class="data row12 col0" >funni</td>
#       <td id="T_dd06b_row12_col1" class="data row12 col1" >662</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dd06b_row13_col0" class="data row13 col0" >mkr</td>
#       <td id="T_dd06b_row13_col1" class="data row13 col1" >659</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dd06b_row14_col0" class="data row14 col0" >men</td>
#       <td id="T_dd06b_row14_col1" class="data row14 col1" >614</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dd06b_row15_col0" class="data row15 col0" >say</td>
#       <td id="T_dd06b_row15_col1" class="data row15 col1" >592</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dd06b_row16_col0" class="data row16 col0" >think</td>
#       <td id="T_dd06b_row16_col1" class="data row16 col1" >592</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dd06b_row17_col0" class="data row17 col0" >get</td>
#       <td id="T_dd06b_row17_col1" class="data row17 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dd06b_row18_col0" class="data row18 col0" >fuck</td>
#       <td id="T_dd06b_row18_col1" class="data row18 col1" >548</td>
#     </tr>
#     <tr>
#       <th id="T_dd06b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_dd06b_row19_col0" class="data row19 col0" >use</td>
#       <td id="T_dd06b_row19_col1" class="data row19 col1" >441</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_gender, y="Count", x="Top Words")
plt.title("Top 20 words in Gender Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Gender Cyberbullying')

# %%
plot_wordcloud('gender')

# %% [markdown]
# # Religion Based Cyberbullying

# %%
religion = Counter([item for sublist in religion_type['tweet_list'] for item in sublist])
top20_religion = pd.DataFrame(religion.most_common(20))
top20_religion.columns = ['Top Words','Count']
top20_religion.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_aff55_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_aff55_row1_col1 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_aff55_row2_col1 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_aff55_row3_col1 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_aff55_row4_col1 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_aff55_row5_col1 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_aff55_row6_col1 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_aff55_row7_col1 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_aff55_row8_col1, #T_aff55_row9_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_aff55_row10_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_aff55_row11_col1 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_aff55_row12_col1 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_aff55_row13_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_aff55_row14_col1, #T_aff55_row15_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_aff55_row16_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_aff55_row17_col1, #T_aff55_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_aff55_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_aff55_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Top Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aff55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aff55_row0_col0" class="data row0 col0" >muslim</td>
#       <td id="T_aff55_row0_col1" class="data row0 col1" >4618</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aff55_row1_col0" class="data row1 col0" >idiot</td>
#       <td id="T_aff55_row1_col1" class="data row1 col1" >3075</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aff55_row2_col0" class="data row2 col0" >islam</td>
#       <td id="T_aff55_row2_col1" class="data row2 col1" >2440</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aff55_row3_col0" class="data row3 col0" >christian</td>
#       <td id="T_aff55_row3_col1" class="data row3 col1" >2132</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aff55_row4_col0" class="data row4 col0" >u</td>
#       <td id="T_aff55_row4_col1" class="data row4 col1" >1922</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aff55_row5_col0" class="data row5 col0" >terrorist</td>
#       <td id="T_aff55_row5_col1" class="data row5 col1" >1378</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aff55_row6_col0" class="data row6 col0" >right</td>
#       <td id="T_aff55_row6_col1" class="data row6 col1" >1289</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aff55_row7_col0" class="data row7 col0" >like</td>
#       <td id="T_aff55_row7_col1" class="data row7 col1" >1276</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aff55_row8_col0" class="data row8 col0" >support</td>
#       <td id="T_aff55_row8_col1" class="data row8 col1" >1251</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aff55_row9_col0" class="data row9 col0" >woman</td>
#       <td id="T_aff55_row9_col1" class="data row9 col1" >1247</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_aff55_row10_col0" class="data row10 col0" >terror</td>
#       <td id="T_aff55_row10_col1" class="data row10 col1" >1182</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_aff55_row11_col0" class="data row11 col0" >radic</td>
#       <td id="T_aff55_row11_col1" class="data row11 col1" >1110</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_aff55_row12_col0" class="data row12 col0" >peopl</td>
#       <td id="T_aff55_row12_col1" class="data row12 col1" >1076</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_aff55_row13_col0" class="data row13 col0" >say</td>
#       <td id="T_aff55_row13_col1" class="data row13 col1" >812</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_aff55_row14_col0" class="data row14 col0" >amp</td>
#       <td id="T_aff55_row14_col1" class="data row14 col1" >769</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_aff55_row15_col0" class="data row15 col0" >know</td>
#       <td id="T_aff55_row15_col1" class="data row15 col1" >759</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_aff55_row16_col0" class="data row16 col0" >human</td>
#       <td id="T_aff55_row16_col1" class="data row16 col1" >744</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_aff55_row17_col0" class="data row17 col0" >kill</td>
#       <td id="T_aff55_row17_col1" class="data row17 col1" >708</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_aff55_row18_col0" class="data row18 col0" >hindu</td>
#       <td id="T_aff55_row18_col1" class="data row18 col1" >688</td>
#     </tr>
#     <tr>
#       <th id="T_aff55_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_aff55_row19_col0" class="data row19 col0" >one</td>
#       <td id="T_aff55_row19_col1" class="data row19 col1" >666</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_religion, y="Count", x="Top Words")
plt.title("Top 20 words in Religion Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Religion Cyberbullying')

# %%
plot_wordcloud('religion')

# %% [markdown]
# # Age based Cyberbullying

# %%
age = Counter([item for sublist in age_type['tweet_list'] for item in sublist])
top20_age = pd.DataFrame(age.most_common(20))
top20_age.columns = ['Top Words','Count']
top20_age.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_9f9fc_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_9f9fc_row1_col1 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_9f9fc_row2_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_9f9fc_row3_col1 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_9f9fc_row4_col1 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_9f9fc_row5_col1, #T_9f9fc_row6_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_9f9fc_row7_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_9f9fc_row8_col1, #T_9f9fc_row9_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_9f9fc_row10_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_9f9fc_row11_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_9f9fc_row12_col1, #T_9f9fc_row13_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_9f9fc_row14_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_9f9fc_row15_col1, #T_9f9fc_row16_col1, #T_9f9fc_row17_col1, #T_9f9fc_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_9f9fc_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_9f9fc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Top Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f9fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f9fc_row0_col0" class="data row0 col0" >bulli</td>
#       <td id="T_9f9fc_row0_col1" class="data row0 col1" >8899</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9f9fc_row1_col0" class="data row1 col0" >school</td>
#       <td id="T_9f9fc_row1_col1" class="data row1 col1" >8426</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9f9fc_row2_col0" class="data row2 col0" >high</td>
#       <td id="T_9f9fc_row2_col1" class="data row2 col1" >4861</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9f9fc_row3_col0" class="data row3 col0" >girl</td>
#       <td id="T_9f9fc_row3_col1" class="data row3 col1" >4616</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9f9fc_row4_col0" class="data row4 col0" >like</td>
#       <td id="T_9f9fc_row4_col1" class="data row4 col1" >2076</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9f9fc_row5_col0" class="data row5 col0" >get</td>
#       <td id="T_9f9fc_row5_col1" class="data row5 col1" >1051</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9f9fc_row6_col0" class="data row6 col0" >one</td>
#       <td id="T_9f9fc_row6_col1" class="data row6 col1" >1044</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9f9fc_row7_col0" class="data row7 col0" >peopl</td>
#       <td id="T_9f9fc_row7_col1" class="data row7 col1" >934</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9f9fc_row8_col0" class="data row8 col0" >got</td>
#       <td id="T_9f9fc_row8_col1" class="data row8 col1" >842</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9f9fc_row9_col0" class="data row9 col0" >kid</td>
#       <td id="T_9f9fc_row9_col1" class="data row9 col1" >809</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9f9fc_row10_col0" class="data row10 col0" >would</td>
#       <td id="T_9f9fc_row10_col1" class="data row10 col1" >762</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9f9fc_row11_col0" class="data row11 col0" >middl</td>
#       <td id="T_9f9fc_row11_col1" class="data row11 col1" >714</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9f9fc_row12_col0" class="data row12 col0" >friend</td>
#       <td id="T_9f9fc_row12_col1" class="data row12 col1" >632</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9f9fc_row13_col0" class="data row13 col0" >im</td>
#       <td id="T_9f9fc_row13_col1" class="data row13 col1" >625</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9f9fc_row14_col0" class="data row14 col0" >year</td>
#       <td id="T_9f9fc_row14_col1" class="data row14 col1" >586</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9f9fc_row15_col0" class="data row15 col0" >go</td>
#       <td id="T_9f9fc_row15_col1" class="data row15 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9f9fc_row16_col0" class="data row16 col0" >look</td>
#       <td id="T_9f9fc_row16_col1" class="data row16 col1" >545</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9f9fc_row17_col0" class="data row17 col0" >amp</td>
#       <td id="T_9f9fc_row17_col1" class="data row17 col1" >527</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9f9fc_row18_col0" class="data row18 col0" >know</td>
#       <td id="T_9f9fc_row18_col1" class="data row18 col1" >511</td>
#     </tr>
#     <tr>
#       <th id="T_9f9fc_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9f9fc_row19_col0" class="data row19 col0" >u</td>
#       <td id="T_9f9fc_row19_col1" class="data row19 col1" >477</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_age, y="Count", x="Top Words")
plt.title("Top 20 words in Age Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Age Cyberbullying')

# %%
plot_wordcloud('age')

# %% [markdown]
# # Ethnicity based Cyberbullying

# %%
ethnicity = Counter([item for sublist in ethnicity_type['tweet_list'] for item in sublist])
top20_ethnicity = pd.DataFrame(ethnicity.most_common(20))
top20_ethnicity.columns = ['Top Words','Count']
top20_ethnicity.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_e2849_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e2849_row1_col1 {
#   background-color: #005f26;
#   color: #f1f1f1;
# }
# #T_e2849_row2_col1 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_e2849_row3_col1 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_e2849_row4_col1 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_e2849_row5_col1 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_e2849_row6_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_e2849_row7_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_e2849_row8_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_e2849_row9_col1 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_e2849_row10_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_e2849_row11_col1 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_e2849_row12_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_e2849_row13_col1 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_e2849_row14_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_e2849_row15_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_e2849_row16_col1, #T_e2849_row17_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_e2849_row18_col1, #T_e2849_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_e2849_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Top Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2849_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2849_row0_col0" class="data row0 col0" >fuck</td>
#       <td id="T_e2849_row0_col1" class="data row0 col1" >5892</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e2849_row1_col0" class="data row1 col0" >nigger</td>
#       <td id="T_e2849_row1_col1" class="data row1 col1" >5456</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e2849_row2_col0" class="data row2 col0" >dumb</td>
#       <td id="T_e2849_row2_col1" class="data row2 col1" >5003</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e2849_row3_col0" class="data row3 col0" >as</td>
#       <td id="T_e2849_row3_col1" class="data row3 col1" >2241</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e2849_row4_col0" class="data row4 col0" >black</td>
#       <td id="T_e2849_row4_col1" class="data row4 col1" >2134</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e2849_row5_col0" class="data row5 col0" >u</td>
#       <td id="T_e2849_row5_col1" class="data row5 col1" >2107</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e2849_row6_col0" class="data row6 col0" >white</td>
#       <td id="T_e2849_row6_col1" class="data row6 col1" >1557</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e2849_row7_col0" class="data row7 col0" >call</td>
#       <td id="T_e2849_row7_col1" class="data row7 col1" >1381</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e2849_row8_col0" class="data row8 col0" >peopl</td>
#       <td id="T_e2849_row8_col1" class="data row8 col1" >1182</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e2849_row9_col0" class="data row9 col0" >rt</td>
#       <td id="T_e2849_row9_col1" class="data row9 col1" >1166</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e2849_row10_col0" class="data row10 col0" >obama</td>
#       <td id="T_e2849_row10_col1" class="data row10 col1" >1112</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e2849_row11_col0" class="data row11 col0" >one</td>
#       <td id="T_e2849_row11_col1" class="data row11 col1" >1058</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e2849_row12_col0" class="data row12 col0" >like</td>
#       <td id="T_e2849_row12_col1" class="data row12 col1" >1035</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e2849_row13_col0" class="data row13 col0" >bitch</td>
#       <td id="T_e2849_row13_col1" class="data row13 col1" >999</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e2849_row14_col0" class="data row14 col0" >ur</td>
#       <td id="T_e2849_row14_col1" class="data row14 col1" >987</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e2849_row15_col0" class="data row15 col0" >say</td>
#       <td id="T_e2849_row15_col1" class="data row15 col1" >817</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e2849_row16_col0" class="data row16 col0" >first</td>
#       <td id="T_e2849_row16_col1" class="data row16 col1" >745</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e2849_row17_col0" class="data row17 col0" >get</td>
#       <td id="T_e2849_row17_col1" class="data row17 col1" >740</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e2849_row18_col0" class="data row18 col0" >anyth</td>
#       <td id="T_e2849_row18_col1" class="data row18 col1" >708</td>
#     </tr>
#     <tr>
#       <th id="T_e2849_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e2849_row19_col0" class="data row19 col0" >racism</td>
#       <td id="T_e2849_row19_col1" class="data row19 col1" >689</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_ethnicity, y="Count", x="Top Words")
plt.title("Top 20 words in Ethnicity Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Ethnicity Cyberbullying')

# %%
plot_wordcloud('ethnicity')

# %% [markdown]
# # Other types of Cyberbullying

# %%
other_cyberbullying = Counter([item for sublist in other_cyberbullying_type['tweet_list'] for item in sublist])
top20_other_cyberbullying = pd.DataFrame(other_cyberbullying.most_common(20))
top20_other_cyberbullying.columns = ['Top Words','Count']
top20_other_cyberbullying.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_5cfda_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_5cfda_row1_col1 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_5cfda_row2_col1 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_5cfda_row3_col1 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_5cfda_row4_col1 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_5cfda_row5_col1 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_5cfda_row6_col1 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_5cfda_row7_col1 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_5cfda_row8_col1, #T_5cfda_row9_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_5cfda_row10_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_5cfda_row11_col1 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_5cfda_row12_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_5cfda_row13_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_5cfda_row14_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_5cfda_row15_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_5cfda_row16_col1, #T_5cfda_row17_col1, #T_5cfda_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_5cfda_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_5cfda_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Top Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cfda_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5cfda_row0_col0" class="data row0 col0" >bulli</td>
#       <td id="T_5cfda_row0_col1" class="data row0 col1" >882</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5cfda_row1_col0" class="data row1 col0" >rt</td>
#       <td id="T_5cfda_row1_col1" class="data row1 col1" >727</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5cfda_row2_col0" class="data row2 col0" >fuck</td>
#       <td id="T_5cfda_row2_col1" class="data row2 col1" >509</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5cfda_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_5cfda_row3_col1" class="data row3 col1" >424</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5cfda_row4_col0" class="data row4 col0" >get</td>
#       <td id="T_5cfda_row4_col1" class="data row4 col1" >393</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5cfda_row5_col0" class="data row5 col0" >peopl</td>
#       <td id="T_5cfda_row5_col1" class="data row5 col1" >353</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5cfda_row6_col0" class="data row6 col0" >go</td>
#       <td id="T_5cfda_row6_col1" class="data row6 col1" >277</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5cfda_row7_col0" class="data row7 col0" >idiot</td>
#       <td id="T_5cfda_row7_col1" class="data row7 col1" >261</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5cfda_row8_col0" class="data row8 col0" >know</td>
#       <td id="T_5cfda_row8_col1" class="data row8 col1" >241</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5cfda_row9_col0" class="data row9 col0" >think</td>
#       <td id="T_5cfda_row9_col1" class="data row9 col1" >237</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5cfda_row10_col0" class="data row10 col0" >would</td>
#       <td id="T_5cfda_row10_col1" class="data row10 col1" >235</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5cfda_row11_col0" class="data row11 col0" >u</td>
#       <td id="T_5cfda_row11_col1" class="data row11 col1" >223</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5cfda_row12_col0" class="data row12 col0" >make</td>
#       <td id="T_5cfda_row12_col1" class="data row12 col1" >215</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5cfda_row13_col0" class="data row13 col0" >one</td>
#       <td id="T_5cfda_row13_col1" class="data row13 col1" >205</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5cfda_row14_col0" class="data row14 col0" >time</td>
#       <td id="T_5cfda_row14_col1" class="data row14 col1" >202</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5cfda_row15_col0" class="data row15 col0" >hate</td>
#       <td id="T_5cfda_row15_col1" class="data row15 col1" >199</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5cfda_row16_col0" class="data row16 col0" >want</td>
#       <td id="T_5cfda_row16_col1" class="data row16 col1" >183</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5cfda_row17_col0" class="data row17 col0" >thing</td>
#       <td id="T_5cfda_row17_col1" class="data row17 col1" >182</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5cfda_row18_col0" class="data row18 col0" >need</td>
#       <td id="T_5cfda_row18_col1" class="data row18 col1" >182</td>
#     </tr>
#     <tr>
#       <th id="T_5cfda_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5cfda_row19_col0" class="data row19 col0" >see</td>
#       <td id="T_5cfda_row19_col1" class="data row19 col1" >178</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_other_cyberbullying, y="Count", x="Top Words")
plt.title("Top 20 words in Other Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Other Cyberbullying')

# %%
plot_wordcloud('other_cyberbullying')

# %% [markdown]
# # Tweets without Cyberbullying

# %%
not_cyberbullying = Counter([item for sublist in not_cyberbullying_type['tweet_list'] for item in sublist])
top20_not_cyberbullying = pd.DataFrame(not_cyberbullying.most_common(20))
top20_not_cyberbullying.columns = ['Top Words','Count']
top20_not_cyberbullying.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_beda4_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_beda4_row1_col1 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_beda4_row2_col1 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_beda4_row3_col1, #T_beda4_row4_col1 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_beda4_row5_col1 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_beda4_row6_col1 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_beda4_row7_col1, #T_beda4_row8_col1 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_beda4_row9_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_beda4_row10_col1 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_beda4_row11_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_beda4_row12_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_beda4_row13_col1, #T_beda4_row14_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_beda4_row15_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_beda4_row16_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_beda4_row17_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_beda4_row18_col1, #T_beda4_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_beda4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Top Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_beda4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_beda4_row0_col0" class="data row0 col0" >mkr</td>
#       <td id="T_beda4_row0_col1" class="data row0 col1" >1674</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_beda4_row1_col0" class="data row1 col0" >bulli</td>
#       <td id="T_beda4_row1_col1" class="data row1 col1" >1102</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_beda4_row2_col0" class="data row2 col0" >rt</td>
#       <td id="T_beda4_row2_col1" class="data row2 col1" >785</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_beda4_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_beda4_row3_col1" class="data row3 col1" >424</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_beda4_row4_col0" class="data row4 col0" >get</td>
#       <td id="T_beda4_row4_col1" class="data row4 col1" >423</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_beda4_row5_col0" class="data row5 col0" >go</td>
#       <td id="T_beda4_row5_col1" class="data row5 col1" >394</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_beda4_row6_col0" class="data row6 col0" >school</td>
#       <td id="T_beda4_row6_col1" class="data row6 col1" >374</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_beda4_row7_col0" class="data row7 col0" >kat</td>
#       <td id="T_beda4_row7_col1" class="data row7 col1" >286</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_beda4_row8_col0" class="data row8 col0" >would</td>
#       <td id="T_beda4_row8_col1" class="data row8 col1" >286</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_beda4_row9_col0" class="data row9 col0" >peopl</td>
#       <td id="T_beda4_row9_col1" class="data row9 col1" >272</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_beda4_row10_col0" class="data row10 col0" >one</td>
#       <td id="T_beda4_row10_col1" class="data row10 col1" >264</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_beda4_row11_col0" class="data row11 col0" >amp</td>
#       <td id="T_beda4_row11_col1" class="data row11 col1" >258</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_beda4_row12_col0" class="data row12 col0" >think</td>
#       <td id="T_beda4_row12_col1" class="data row12 col1" >242</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_beda4_row13_col0" class="data row13 col0" >u</td>
#       <td id="T_beda4_row13_col1" class="data row13 col1" >231</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_beda4_row14_col0" class="data row14 col0" >know</td>
#       <td id="T_beda4_row14_col1" class="data row14 col1" >229</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_beda4_row15_col0" class="data row15 col0" >time</td>
#       <td id="T_beda4_row15_col1" class="data row15 col1" >224</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_beda4_row16_col0" class="data row16 col0" >make</td>
#       <td id="T_beda4_row16_col1" class="data row16 col1" >219</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_beda4_row17_col0" class="data row17 col0" >love</td>
#       <td id="T_beda4_row17_col1" class="data row17 col1" >207</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_beda4_row18_col0" class="data row18 col0" >andr</td>
#       <td id="T_beda4_row18_col1" class="data row18 col1" >194</td>
#     </tr>
#     <tr>
#       <th id="T_beda4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_beda4_row19_col0" class="data row19 col0" >need</td>
#       <td id="T_beda4_row19_col1" class="data row19 col1" >191</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_not_cyberbullying, y="Count", x="Top Words")
plt.title("Top 20 words in Not Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Not Cyberbullying')

# %%
plot_wordcloud('not_cyberbullying')

# %%
data.head()
# Out:
#                                                 text          sentiment  \
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    sentiment_encoded                                       cleaned_text  \
# 0                  6                 word katandandr food crapilici mkr
# 1                  6  aussietv white mkr theblock imacelebrityau tod...
# 2                  6                     classi whore red velvet cupcak
# 3                  6  meh p thank head concern anoth angri dude twitter
# 4                  6  isi account pretend kurdish account like islam...
#
#                                           tweet_list  text_len
# 0           [word, katandandr, food, crapilici, mkr]         5
# 1  [aussietv, white, mkr, theblock, imacelebritya...        11
# 2               [classi, whore, red, velvet, cupcak]         5
# 3  [meh, p, thank, head, concern, anoth, angri, d...         9
# 4  [isi, account, pretend, kurdish, account, like...         8

# %%
sentiments = ["religion", "age", "ethnicity", "gender", "other_cyberbullying","not_cyberbullying"]

# %% [markdown]
# # Splitting Data into Train and Test Sets

# %%
X,Y = data['cleaned_text'],data['sentiment_encoded']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, stratify =Y, random_state = 42)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (31255,) (31255,) (13395,) (13395,)

# %% [markdown]
# ## tf-idf Vectorization

# %%
tf_idf = TfidfVectorizer()
X_train_tf = tf_idf.fit_transform(X_train)
X_test_tf = tf_idf.transform(X_test)
print(X_train_tf.shape)
print(X_test_tf.shape)
# Out:
# (31255, 29111)
# (13395, 29111)

# %% [markdown]
# # Trying Different ML Models

# %% [markdown]
# ## Logistic Regression

# %%
log_reg = LogisticRegression()

# %%
log_cv_score = cross_val_score(log_reg,X_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)

# %%
mean_log_cv = np.mean(log_cv_score)
mean_log_cv
# Out:
# 0.8228272280708214

# %% [markdown]
# ## Support Vector Classifier

# %%
lin_svc = LinearSVC()

# %%
lin_svc_cv_score = cross_val_score(lin_svc,X_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_lin_svc_cv = np.mean(lin_svc_cv_score)
mean_lin_svc_cv
# Out:
# 0.8220066371295554

# %% [markdown]
# ## Naive Bayes Classifier

# %%
multiNB = MultinomialNB()

# %%
multiNB_cv_score = cross_val_score(multiNB,X_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_multiNB_cv = np.mean(multiNB_cv_score)
mean_multiNB_cv
# Out:
# 0.6708019945279682

# %% [markdown]
# ## Decison Tree Classifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree_cv_score = cross_val_score(dtree,X_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_dtree_cv = np.mean(dtree_cv_score)
mean_dtree_cv
# Out:
# 0.8087938020774486

# %% [markdown]
# ## RandomForest Classifier

# %%
rand_forest = RandomForestClassifier()

# %%
rand_forest_cv_score = cross_val_score(rand_forest,X_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_rand_forest_cv = np.mean(rand_forest_cv_score)
mean_rand_forest_cv
# Out:
# 0.8299577325897154

# %% [markdown]
# ## Adaboost Classifier

# %%
adab = AdaBoostClassifier()

# %%
adab_cv_score = cross_val_score(adab,X_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_adab_cv = np.mean(adab_cv_score)
mean_adab_cv
# Out:
# 0.760119208505768

# %% [markdown]
# ## By trying different models we can see logistic regression, svm and random forest classifier performed similarly, so among these we will go with svm model as it is more generalised and light

# %% [markdown]
# ## Fine Tuning Support Vector Classifier

# %%
svc1 = LinearSVC()
param_grid = {'C':[0.0001,0.001,0.01,0.1,1,10],
             'loss':['hinge','squared_hinge'],
             'fit_intercept':[True,False]}
grid_search = GridSearchCV(svc1,param_grid,cv=5,scoring='f1_macro',n_jobs=-1,verbose=0,return_train_score=True)
grid_search.fit(X_train_tf,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearSVC(), n_jobs=-1,
#              param_grid={'C': [0.0001, 0.001, 0.01, 0.1, 1, 10],
#                          'fit_intercept': [True, False],
#                          'loss': ['hinge', 'squared_hinge']},
#              return_train_score=True, scoring='f1_macro')

# %%
grid_search.best_estimator_
# Out:
# LinearSVC(C=1, loss='hinge')

# %%
grid_search.best_score_
# Out:
# 0.8244012024546198

# %% [markdown]
# # Model Evaluation

# %%
lin_svc.fit(X_train_tf,y_train)
y_pred = lin_svc.predict(X_test_tf)

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names)
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('Truth')
    plt.xlabel('Prediction')

# %%
cm = confusion_matrix(y_test,y_pred)
print_confusion_matrix(cm,sentiments)

# %%
print('Classification Report:\n',classification_report(y_test, y_pred, target_names=sentiments))
# Out:
# Classification Report:
#                       precision    recall  f1-score   support
#
#            religion       0.94      0.95      0.94      2386
#                 age       0.93      0.97      0.95      2365
#           ethnicity       0.97      0.99      0.98      2331
#              gender       0.89      0.85      0.87      2286
# other_cyberbullying       0.58      0.59      0.59      1734
#   not_cyberbullying       0.63      0.60      0.61      2293
#
#            accuracy                           0.84     13395
#           macro avg       0.82      0.83      0.82     13395
#        weighted avg       0.84      0.84      0.84     13395

# %%
pickle.dump(tf_idf, open('vectorizer.pkl', 'wb'))
pickle.dump(lin_svc, open('model.pkl', 'wb'))
